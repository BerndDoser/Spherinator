# %%
from spherinator.data import ParquetDataset

ds = ParquetDataset("/home/doserbd/data/illustris/pointcloud", "stars_pos")

print("Number of rows:", len(ds))
ds.data[0].dtype
# Out:
# Number of rows: 2
# dtype('O')

# %%
batch = ds[0]
batch
# Out:
# array([array([1.2, 3.4, 5.1], dtype=float32),
#        array([2.2, 4.5, 6.7], dtype=float32)], dtype=object)

# %%
import torch

batch_2d_torch = torch.tensor([x for x in batch], dtype=torch.float32)
batch_2d_torch
# Out:
# tensor([[1.2000, 3.4000, 5.1000],
#         [2.2000, 4.5000, 6.7000]])
