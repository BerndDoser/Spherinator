# %%
from spherinator.data import ParquetDataset

# ds = ParquetDataset("../data/Illustris_TNG_SKIRT_SDSS", "data")
# ds = ParquetDataset("/hits/basement/its/doserbd/data/SKIRT_synthetic_images_small/parquet-128", "data")
# ds = ParquetDataset("/hits/basement/its/doserbd/data/SKIRT_synthetic_images/parquet-v3-128", "data")
ds = ParquetDataset("/local/SKIRT_synthetic_images/parquet-v3-128", "data")

print("Number of rows:", len(ds))
ds.data[0].dtype
# Out:
# Number of rows: 58033
# dtype('float32')

# %%
batch = ds[0]

# %%
import numpy as np
from PIL import Image

data = batch.cpu().detach().numpy().reshape(3, 128, 128).transpose(1, 2, 0) * 255
image = Image.fromarray(data.astype(np.uint8), "RGB")
image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>
